# %% [markdown]
# For Regular Indexing

# %%
import pandas as pd
import re
from sklearn.feature_extraction.text import CountVectorizer
from nltk.stem import PorterStemmer, SnowballStemmer, LancasterStemmer

# %%
input_file = r"D:\DownLoad\projects\Search Engine\Olivia_Searchengine\datacollection\output\cran_preprocessed_modern.csv"

# %%
df=pd.read_csv(input_file)

# %%
df.head()
# Out:
#    Doc_NO                                              Title  \
# 0       1  experimental investigation of the aerodynamics...
# 1       2  simple shear flow past a flat plate in an inco...
# 2       3  the boundary layer in simple shear flow past a...
# 3       4  approximate solutions of the incompressible la...
# 4       5  one-dimensional transient heat conduction into...
#
#                                                  Bib  \
# 0                         j. ae. scs. 25, 1958, 324.
# 1  department of aeronautical engineering, rensse...
# 2  department of mathematics, university of manch...
# 3                         j. ae. scs. 22, 1955, 728.
# 4                         j. ae. scs. 24, 1957, 924.
#
#                                                 Text  \
# 0  experimental investigation of the aerodynamics...
# 1  simple shear flow past a flat plate in an inco...
# 2  the boundary layer in simple shear flow past a...
# 3  approximate solutions of the incompressible la...
# 4  one-dimensional transient heat conduction into...
#
#                                       Processed_Text
# 0  experiment investig of the aerodynam of a wing...
# 1  simpl shear flow past a flat plate in an incom...
# 2  the boundari layer in simpl shear flow past a ...
# 3  approxim solut of the incompress laminar bound...
# 4  onedimension transient heat conduct into a dou...

# %%
import pandas as pd
import pyterrier as pt
import os

def Regular_indexing():
    if not pt.started():
        pt.init()
        print("Java Virtual Machine started!")

    input_file = r"D:\DownLoad\projects\Search Engine\Olivia_Searchengine\datacollection\output\cran_preprocessed_modern.csv"
    df = pd.read_csv(input_file)
    df["docno"] = df["Doc_NO"].astype(str)

    # Validation checks
    assert df["Processed_Text"].notnull().all(), "Processed_Text has null values!"
    assert df["docno"].notnull().all(), "docno has null values!"
    assert df["docno"].is_unique, "docno values are not unique!"

    index_path = os.path.abspath("./CranfieldTitleIndex")
    if not os.path.exists(index_path) or not os.listdir(index_path):
        print("\nIndexing documents...")
        indexer = pt.DFIndexer(index_path, overwrite=True)
        index_ref = indexer.index(df["Processed_Text"], df["docno"])
        print("Index created at:", index_ref.toString())
    else:
        print("Index already exists at:", index_path)

# %%
index_path = os.path.abspath("./CranfieldTitleIndex")
index = pt.IndexFactory.of(index_path)

# %%
from nltk.stem import SnowballStemmer

def search_term_regular_indexing(query_term):
    index_path = os.path.abspath("./CranfieldTitleIndex")
    if not os.path.exists(index_path) or not os.listdir(index_path):
        print("Index not found. Run Regular_indexing() first.")
        return

    index = pt.IndexFactory.of(index_path)
    stemmer = SnowballStemmer("english")
    for term in query_term :
        term = term.lower()
        stemmed_term = stemmer.stem(term)

        print(f"\nSearching for: '{term}' (stemmed: '{stemmed_term}')")

        try:
            lexicon = index.getLexicon()
            if stemmed_term not in lexicon:
                print(f"Term '{stemmed_term}' not found in the index.")
                return

            pointer = lexicon[stemmed_term]
            print(f"Found term '{stemmed_term}' with stats: {pointer.toString()}")

            postings = index.getInvertedIndex().getPostings(pointer)
            meta = index.getMetaIndex()

            print("Documents containing the term:")
            for posting in postings:
                doc_id = posting.getId()
                docno = meta.getItem("docno", doc_id)
                doc_length = posting.getDocumentLength()
                print(f"- Doc ID: {doc_id} (docno: {docno}), Length: {doc_length}")
        except Exception as e:
            print("Search failed:", e)

# %% [markdown]
# Adding Boolean Retreivel

# %%
def boolean_query(query_terms, operator):
    df=pd.read_csv(r"D:\DownLoad\projects\Search Engine\Olivia_Searchengine\datacollection\output\cran_preprocessed_modern.csv")
    # Convert all query terms to lowercase
    query_terms = [term.lower() for term in query_terms]

    # Use CountVectorizer to get binary term-document matrix
    vectorizer = CountVectorizer(binary=True, stop_words="english")
    X = vectorizer.fit_transform(df['Title'])
    terms = vectorizer.get_feature_names_out()
    td_matrix = X.toarray()

    # Create a query vector
    query_vector = [1 if term in query_terms else 0 for term in terms]

    result = td_matrix @ query_vector  # Matrix multiplication (dot product)

    if operator.upper() == "AND":
        return df['Doc_NO'][[count == len(query_terms) for count in result]].tolist()
    elif operator.upper() == "OR":
        return df['Doc_NO'][[count > 0 for count in result]].tolist()
    elif operator.upper() == "NOT":
        return df['Doc_NO'][[count == 0 for count in result]].tolist()
    else:
        raise ValueError("Operator must be 'AND', 'OR', or 'NOT'")

# %%
print("AND:", boolean_query( ["experimental", "investigation"], "AND"))
# Out:
# AND: [1, 84, 189, 372, 423, 497, 569, 662, 766, 816, 836, 858, 1062, 1074, 1075, 1098, 1156, 1159, 1364]

# %% [markdown]
# Adding Query preprocessing

# %%
def preprocess_query(query, stemmer=SnowballStemmer('english')):
    query = query.lower()
    query = re.sub(r'[^a-zA-Z\s]', '', query)
    query = re.sub(r'\s+', ' ', query).strip()
    tokens = query.split()
    stemmed_tokens = [stemmer.stem(token) for token in tokens]
    return stemmed_tokens


sample_query = 'Experimental Aerodynamics Wing'
print('Sample query:', sample_query)
print('Preprocessed query tokens:', preprocess_query(sample_query))
# Out:
# Sample query: Experimental Aerodynamics Wing
# Preprocessed query tokens: ['experiment', 'aerodynam', 'wing']

# %%
def retrieve_documents(query_tokens, df):
    index_path = os.path.abspath("./CranfieldTitleIndex")
    if not os.path.exists(index_path) or not os.listdir(index_path):
        print("Index not found. Run Regular_indexing() first.")
        return

    index = pt.IndexFactory.of(index_path)
    lexicon = index.getLexicon()
    doc_sets = []

    for token in query_tokens:
        try:
            pointer = lexicon[token]
            postings = index.getInvertedIndex().getPostings(pointer)
            doc_ids = [posting.getId() for posting in postings]
            doc_sets.append(set(doc_ids))
        except KeyError:
            print(f"Term '{token}' not found in index.")
            return []

    if not doc_sets:
        return []
    common_docs = list(set.intersection(*doc_sets))

    results = []
    for doc_id in common_docs:
        docno = df['Doc_NO'].iloc[doc_id]
        title = df['Title'].iloc[doc_id]
        processed_text = df['Processed_Text'].iloc[doc_id]
        results.append({
            'doc_id': doc_id,
            'docno': docno,
            'title': title,
            'processed_text': processed_text
        })
    for doc in results[:2]:
        print(f"Docno: {doc['docno']}, Title: {doc['title']}")

    

test_query = 'experimental investigation' #aerodynamics wing
test_tokens = preprocess_query(test_query)
docs = retrieve_documents(test_tokens, df)
print(f'\nDocuments retrieved for query "{test_query}":')
# for doc in docs[:2]:
#     print(f"Docno: {doc['docno']}, Title: {doc['title']}")
# Out:
# Term 'experiment' not found in index.
#
# Documents retrieved for query "experimental investigation":

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
def rank_documents(documents, query_tokens):
    if not documents:
        return []

    corpus = [doc['processed_text'] for doc in documents]
    query = ' '.join(query_tokens)

    vectorizer = TfidfVectorizer(vocabulary=query_tokens)
    try:
        tfidf_matrix = vectorizer.fit_transform(corpus)
        scores = tfidf_matrix.sum(axis=1).A1
    except ValueError as e:
        print('TF-IDF calculation failed:', e)
        scores = [0] * len(documents)

    for i, doc in enumerate(documents):
        doc['tfidf_score'] = scores[i]

    ranked_docs = sorted(documents, key=lambda x: x['tfidf_score'], reverse=True)
    return ranked_docs

ranked_docs = rank_documents(docs, test_tokens)
print(f'\nTop ranked documents for query "{test_query}":')
for doc in ranked_docs[:2]:
    print(f"Docno: {doc['docno']}, Title: {doc['title']}, TF-IDF Score: {doc['tfidf_score']:.4f}")
# Out:
# Top ranked documents for query "experimental investigation":

# %%
def boolean_search(query, df, top_k=5):
    query = query.lower().strip()
    tokens = re.findall(r'\b\w+\b|and|or|not', query)
    stemmer = SnowballStemmer('english')
    index_path = os.path.abspath("./CranfieldTitleIndex")
    if not os.path.exists(index_path) or not os.listdir(index_path):
        print("Index not found. Run Regular_indexing() first.")
        return

    index = pt.IndexFactory.of(index_path)
    
    lexicon = index.getLexicon()
    doc_sets = []
    current_term = ''
    operator = 'AND'

    for token in tokens:
        if token in ['and', 'or', 'not']:
            operator = token.upper()
            continue
        stemmed = stemmer.stem(token)
        doc_ids = set()
        if stemmed in lexicon:
            postings = index.getInvertedIndex().getPostings(lexicon[stemmed])
            doc_ids = {posting.getId() for posting in postings}
        if operator == 'NOT':
            all_docs = set(range(len(df)))
            doc_ids = all_docs - doc_ids
            operator = 'AND'
        doc_sets.append((doc_ids, operator))
        current_term = stemmed

    if not doc_sets:
        print('No valid terms found.')
        return []

    result_docs = doc_sets[0][0]
    for i in range(1, len(doc_sets)):
        docs, op = doc_sets[i]
        if op == 'AND':
            result_docs &= docs
        elif op == 'OR':
            result_docs |= docs

    documents = [{'doc_id': doc_id, 'docno': df['Doc_NO'].iloc[doc_id], 'title': df['Title'].iloc[doc_id], 'processed_text': df['Processed_Text'].iloc[doc_id]} for doc_id in result_docs]
    query_tokens = [stemmer.stem(t) for t in re.findall(r'\b\w+\b', query)]
    ranked_docs = rank_documents(documents, query_tokens)

    print(f'Boolean search results for "{query}":')
    for i, doc in enumerate(ranked_docs[:top_k], 1):
        print(f'{i}. Docno: {doc["docno"]}, Title: {doc["title"]}, TF-IDF Score: {doc["tfidf_score"]:.4f}')
    return ranked_docs

boolean_search('aerodynamics AND wing NOT supersonic',df)
boolean_search('boundary OR layer',df)
# Out:
# Boolean search results for "aerodynamics and wing not supersonic":
# 1. Docno: 749, Title: the aerodynamic effects of aspect ratio and sweepback
#     on wing flutter ., TF-IDF Score: 1.6356
# 2. Docno: 1334, Title: calculated spanwise lift distributions and aerodynamic
#     influence coefficients for swept wings in subsonic
#     flow ., TF-IDF Score: 1.6356
# 3. Docno: 1115, Title: measurements of aerodynamic forces for various mean
#     angles of attack on an airfoil oscillating in pitch
#     and on two finite-span wings oscillating in bending
#     with emphasis on damping in the stall ., TF-IDF Score: 1.6356
# 4. Docno: 1164, Title: effect of ground proximity on the aerodynamic characteristics
#     of a four- engined vertical take-off and landing transport
#     airplane model with tilting wing and propellers ., TF-IDF Score: 1.4172
# 5. Docno: 748, Title: subsonic aerodynamic flutter derivatives for wings and control surfaces,
#     /compressible and incompressible flow/ ., TF-IDF Score: 1.4172
# Boolean search results for "boundary or layer":
# 1. Docno: 3, Title: the boundary layer in simple shear flow past a flat plate ., TF-IDF Score: 1.4142
# 2. Docno: 4, Title: approximate solutions of the incompressible laminar
#     boundary layer equations for a plate in shear flow ., TF-IDF Score: 1.4142
# 3. Docno: 7, Title: the effect of controlled three-dimensional roughness
#     on boundary layer transition at supersonic speeds ., TF-IDF Score: 1.4142
# 4. Docno: 8, Title: measurements of the effect of two-dimensional and three-dimensional
#     roughness elements on boundary layer transition ., TF-IDF Score: 1.4142
# 5. Docno: 16, Title: transformation of the compressible turbulent boundary
#     layer ., TF-IDF Score: 1.4142
# [{'doc_id': 2,
#   'docno': np.int64(3),
#   'title': 'the boundary layer in simple shear flow past a flat plate .',
#   'processed_text': 'the boundari layer in simpl shear flow past a flat plate',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 3,
#   'docno': np.int64(4),
#   'title': 'approximate solutions of the incompressible laminar\n    boundary layer equations for a plate in shear flow .',
#   'processed_text': 'approxim solut of the incompress laminar boundari layer equat for a plate in shear flow',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 6,
#   'docno': np.int64(7),
#   'title': 'the effect of controlled three-dimensional roughness\n    on boundary layer transition at supersonic speeds .',
#   'processed_text': 'the effect of control threedimension rough on boundari layer transit at superson speed',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 7,
#   'docno': np.int64(8),
#   'title': 'measurements of the effect of two-dimensional and three-dimensional\n    roughness elements on boundary layer transition .',
#   'processed_text': 'measur of the effect of twodimension and threedimension rough element on boundari layer transit',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 15,
#   'docno': np.int64(16),
#   'title': 'transformation of the compressible turbulent boundary\n    layer .',
#   'processed_text': 'transform of the compress turbul boundari layer',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 22,
#   'docno': np.int64(23),
#   'title': 'skin-friction and heat transfer characteristics of\n    a laminar boundary layer on a cylinder in axial incompressible\n    flow .',
#   'processed_text': 'skinfrict and heat transfer characterist of a laminar boundari layer on a cylind in axial incompress flow',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 39,
#   'docno': np.int64(40),
#   'title': 'experiments on boundary layer transition at\n    supersonic speeds .',
#   'processed_text': 'experi on boundari layer transit at superson speed',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 42,
#   'docno': np.int64(43),
#   'title': 'the relation between wall temperature and the effect\n    of roughness on boundary layer transition .',
#   'processed_text': 'the relat between wall temperatur and the effect of rough on boundari layer transit',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 48,
#   'docno': np.int64(49),
#   'title': 'temperature and velocity profiles in the compressible\n    laminar boundary layer with arbitrary distribution\n    of surface temperature .',
#   'processed_text': 'temperatur and veloc profil in the compress laminar boundari layer with arbitrari distribut of surfac temperatur',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 49,
#   'docno': np.int64(50),
#   'title': 'investigation of laminar boundary layer in compressible\n    fluids using the crocco method .',
#   'processed_text': 'investig of laminar boundari layer in compress fluid use the crocco method',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1073,
#   'docno': np.int64(1076),
#   'title': 'an approximate method for determining the displacement effects and\n    viscous drag of laminar boundary layers in two-dimensional hypersonic\n    flow .',
#   'processed_text': 'an approxim method for determin the displac effect and viscous drag of laminar boundari layer in twodimension hyperson flow',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 53,
#   'docno': np.int64(54),
#   'title': 'method for calculation of compressible laminar boundary\n    layer characteristics in axial pressure gradient with\n    zero heat transfer .',
#   'processed_text': 'method for calcul of compress laminar boundari layer characterist in axial pressur gradient with zero heat transfer',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 54,
#   'docno': np.int64(55),
#   'title': 'separation, stability and other properties of compressible\n    laminar boundary layer with pressure gradient and heat\n    transfer .',
#   'processed_text': 'separ stabil and other properti of compress laminar boundari layer with pressur gradient and heat transfer',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 61,
#   'docno': np.int64(62),
#   'title': 'similar solutions for the compressible laminar boundary\n    layer with heat transfer and pressure gradient .',
#   'processed_text': 'similar solut for the compress laminar boundari layer with heat transfer and pressur gradient',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 70,
#   'docno': np.int64(71),
#   'title': 'laminar boundary layer behind shock advancing into\n    stationary fluid .',
#   'processed_text': 'laminar boundari layer behind shock advanc into stationari fluid',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 72,
#   'docno': np.int64(73),
#   'title': 'investigation of the stability of the laminar boundary\n    layer in a compressible fluid .',
#   'processed_text': 'investig of the stabil of the laminar boundari layer in a compress fluid',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 78,
#   'docno': np.int64(79),
#   'title': 'effects of extreme surface cooling on boundary layer\n    transition .',
#   'processed_text': 'effect of extrem surfac cool on boundari layer transit',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 79,
#   'docno': np.int64(80),
#   'title': 'effect of distributed three-dimensional roughness and\n    surface cooling on boundary layer transition and lateral\n    spread of turbulence at supersonic speeds .',
#   'processed_text': 'effect of distribut threedimension rough and surfac cool on boundari layer transit and later spread of turbul at superson speed',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 93,
#   'docno': np.int64(94),
#   'title': 'the transverse curvature effect in compressible axially\n    symmetric laminar boundary layer flow .',
#   'processed_text': 'the transvers curvatur effect in compress axial symmetr laminar boundari layer flow',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 103,
#   'docno': np.int64(104),
#   'title': 'similar solutions of a free convection boundary layer\n    equation for an electrically conducting fluid .',
#   'processed_text': 'similar solut of a free convect boundari layer equat for an electr conduct fluid',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 104,
#   'docno': np.int64(105),
#   'title': 'the asymptotic boundary layer on a circular cylinder\n    in axial incompressible flow .',
#   'processed_text': 'the asymptot boundari layer on a circular cylind in axial incompress flow',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 110,
#   'docno': np.int64(111),
#   'title': 'the laminar boundary layer equation: a method of solution\n    by means of an automatic computer .',
#   'processed_text': 'the laminar boundari layer equat a method of solut by mean of an automat comput',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1146,
#   'docno': np.int64(1149),
#   'title': 'similar temperature boundary layers .',
#   'processed_text': 'similar temperatur boundari layer',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 124,
#   'docno': np.int64(125),
#   'title': 'measurements of skin friction of the compressible turbulent\n    boundary layer on a cone with foreign gas injection .',
#   'processed_text': 'measur of skin friction of the compress turbul boundari layer on a cone with foreign gas inject',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 127,
#   'docno': np.int64(128),
#   'title': 'effects of free stream vorticity on the behaviour of\n    a viscous boundary layer .',
#   'processed_text': 'effect of free stream vortic on the behaviour of a viscous boundari layer',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1151,
#   'docno': np.int64(1154),
#   'title': 'on the influence of wall boundary layers in closed transonic test\n    sections .',
#   'processed_text': 'on the influenc of wall boundari layer in close transon test section',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1152,
#   'docno': np.int64(1155),
#   'title': 'some experimental investigations on the influence of wall boundary\n    layers upon wind tunnel measurements at high subsonic speeds .',
#   'processed_text': 'some experiment investig on the influenc of wall boundari layer upon wind tunnel measur at high subson speed',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 132,
#   'docno': np.int64(133),
#   'title': 'some effects of surface curvature on laminar boundary\n    layer flow .',
#   'processed_text': 'some effect of surfac curvatur on laminar boundari layer flow',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 133,
#   'docno': np.int64(134),
#   'title': 'note on an interaction between the boundary layer and the inviscid\n    flow .',
#   'processed_text': 'note on an interact between the boundari layer and the inviscid flow',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 144,
#   'docno': np.int64(145),
#   'title': 'skin friction in the laminar boundary layer in compressible\n    flow .',
#   'processed_text': 'skin friction in the laminar boundari layer in compress flow',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 149,
#   'docno': np.int64(150),
#   'title': 'integration of the boundary layer equations .',
#   'processed_text': 'integr of the boundari layer equat',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 154,
#   'docno': np.int64(155),
#   'title': 'on the solution of the laminar boundary layer equations .',
#   'processed_text': 'on the solut of the laminar boundari layer equat',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1179,
#   'docno': np.int64(1182),
#   'title': 'an approximate solution for laminar boundary layer flow .',
#   'processed_text': 'an approxim solut for laminar boundari layer flow',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1182,
#   'docno': np.int64(1185),
#   'title': 'an integral method for calculating heat and mass transfer\n    in laminar boundary layers .',
#   'processed_text': 'an integr method for calcul heat and mass transfer in laminar boundari layer',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1184,
#   'docno': np.int64(1187),
#   'title': 'shock-induced boundary layer separation in overexpanded conical exhaust\n    nozzles .',
#   'processed_text': 'shockinduc boundari layer separ in overexpand conic exhaust nozzl',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1189,
#   'docno': np.int64(1192),
#   'title': 'an integral method for calculation of supersonic laminar\n    boundary layer with heat transfer on yawed cone .',
#   'processed_text': 'an integr method for calcul of superson laminar boundari layer with heat transfer on yaw cone',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 169,
#   'docno': np.int64(170),
#   'title': 'the interaction of a reflected shock wave with the\n    boundary layer in a shock tube .',
#   'processed_text': 'the interact of a reflect shock wave with the boundari layer in a shock tube',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1196,
#   'docno': np.int64(1199),
#   'title': 'theoretical investigations of a supersonic laminar\n    boundary layer with foreign-gas injection .',
#   'processed_text': 'theoret investig of a superson laminar boundari layer with foreignga inject',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1202,
#   'docno': np.int64(1205),
#   'title': 'effects of cooling on boundary layer transition on\n    a hemi- sphere in simulated hypersonic flow .',
#   'processed_text': 'effect of cool on boundari layer transit on a hemi sphere in simul hyperson flow',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 179,
#   'docno': np.int64(180),
#   'title': 'boundary layer over a flat plate in presence of shear\n    flow .',
#   'processed_text': 'boundari layer over a flat plate in presenc of shear flow',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1208,
#   'docno': np.int64(1211),
#   'title': 'boundary layer transition at supersonic\n    speeds-three-dimensional roughness effects (spheres).',
#   'processed_text': 'boundari layer transit at superson speedsthreedimension rough effect sphere',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1217,
#   'docno': np.int64(1220),
#   'title': 'boundary layer transition in the presence of streamwise\n    vortices .',
#   'processed_text': 'boundari layer transit in the presenc of streamwis vortic',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1222,
#   'docno': np.int64(1225),
#   'title': 'the effect of adverse pressure gradients on the characteristics of\n    turbulent boundary layers in supersonic streams .',
#   'processed_text': 'the effect of advers pressur gradient on the characterist of turbul boundari layer in superson stream',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1223,
#   'docno': np.int64(1226),
#   'title': 'heat transfer in the laminar boundary layer with ablation\n    of vapor of arbitrary molecular weight .',
#   'processed_text': 'heat transfer in the laminar boundari layer with ablat of vapor of arbitrari molecular weight',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1225,
#   'docno': np.int64(1228),
#   'title': 'leading-edge separation of laminar boundary layers\n    in supersonic flow .',
#   'processed_text': 'leadingedg separ of laminar boundari layer in superson flow',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 206,
#   'docno': np.int64(207),
#   'title': 'laminar boundary layer oscillations and transition\n    on a flat plate .',
#   'processed_text': 'laminar boundari layer oscil and transit on a flat plate',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 208,
#   'docno': np.int64(209),
#   'title': 'boundary layer induced noise in the interior of aircraft .',
#   'processed_text': 'boundari layer induc nois in the interior of aircraft',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1233,
#   'docno': np.int64(1236),
#   'title': 'the stagnation point boundary layer in the presence\n    of an applied magnetic field .',
#   'processed_text': 'the stagnat point boundari layer in the presenc of an appli magnet field',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1234,
#   'docno': np.int64(1237),
#   'title': 'foreign-gas injection into a compressible turbulent\n    boundary layer on a flat plate .',
#   'processed_text': 'foreignga inject into a compress turbul boundari layer on a flat plate',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1237,
#   'docno': np.int64(1240),
#   'title': 'nonsimilar solutions of the compressible laminar boundary\n    layer equations with applications to the upstream-transpiration\n    cooling problem .',
#   'processed_text': 'nonsimilar solut of the compress laminar boundari layer equat with applic to the upstreamtranspir cool problem',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1238,
#   'docno': np.int64(1241),
#   'title': 'the turbulent boundary layer on chemically active ablating\n    surfaces .',
#   'processed_text': 'the turbul boundari layer on chemic activ ablat surfac',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1251,
#   'docno': np.int64(1254),
#   'title': 'combustion in the boundary layer on a porous surface .',
#   'processed_text': 'combust in the boundari layer on a porous surfac',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1257,
#   'docno': np.int64(1260),
#   'title': 'on the response of the laminar boundary layer to small\n    fluctuations of the free-stream velocity .',
#   'processed_text': 'on the respons of the laminar boundari layer to small fluctuat of the freestream veloc',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1258,
#   'docno': np.int64(1261),
#   'title': 'a method of calculating velocity distribution for turbulent\n    boundary layers in adverse pressure distributions .',
#   'processed_text': 'a method of calcul veloc distribut for turbul boundari layer in advers pressur distribut',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1260,
#   'docno': np.int64(1263),
#   'title': 'turbulent heat transfer through a highly cooled, partially\n    dissociated boundary layer .',
#   'processed_text': 'turbul heat transfer through a high cool partial dissoci boundari layer',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1261,
#   'docno': np.int64(1264),
#   'title': 'boundary layer transition and heat transfer in shock\n    tubes .',
#   'processed_text': 'boundari layer transit and heat transfer in shock tube',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1265,
#   'docno': np.int64(1268),
#   'title': 'stable combustion of a high-velocity gas in a heated\n    boundary layer .',
#   'processed_text': 'stabl combust of a highveloc gas in a heat boundari layer',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 243,
#   'docno': np.int64(244),
#   'title': 'an improved smoke generator for use in the visualisation\n    of airflow, particularly boundary layer flow at high\n    reynolds numbers .',
#   'processed_text': 'an improv smoke generat for use in the visualis of airflow particular boundari layer flow at high reynold number',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1275,
#   'docno': np.int64(1278),
#   'title': 'transition in a separated laminar boundary layer .',
#   'processed_text': 'transit in a separ laminar boundari layer',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 253,
#   'docno': np.int64(254),
#   'title': 'boundary layers with suction and injection . a review\n    of published work on skin friction .',
#   'processed_text': 'boundari layer with suction and inject a review of publish work on skin friction',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 254,
#   'docno': np.int64(255),
#   'title': 'an approximate solution of the turbulent boundary layer\n    equations in incompressible and compressible .',
#   'processed_text': 'an approxim solut of the turbul boundari layer equat in incompress and compress',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 255,
#   'docno': np.int64(256),
#   'title': 'an experimental study of the glancing interaction between\n    a shock wave and a turbulent boundary layer .',
#   'processed_text': 'an experiment studi of the glanc interact between a shock wave and a turbul boundari layer',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1281,
#   'docno': np.int64(1284),
#   'title': 'the transition to tubulence in a boundary layer on\n    a blunt cone in supersonic flow .',
#   'processed_text': 'the transit to tubul in a boundari layer on a blunt cone in superson flow',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 259,
#   'docno': np.int64(260),
#   'title': 'a critical review of skin friction and heat transfer\n    solutions of the laminar boundary layer of a flat plate .',
#   'processed_text': 'a critic review of skin friction and heat transfer solut of the laminar boundari layer of a flat plate',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 260,
#   'docno': np.int64(261),
#   'title': 'experiments on axi-symmetric boundary layers along\n    a long cylinder in incompressible flow .',
#   'processed_text': 'experi on axisymmetr boundari layer along a long cylind in incompress flow',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 264,
#   'docno': np.int64(265),
#   'title': 'some instabilities arising from the interaction between\n    shock waves and boundary layer .',
#   'processed_text': 'some instabl aris from the interact between shock wave and boundari layer',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 270,
#   'docno': np.int64(271),
#   'title': 'an experimental test of compressibility transformation\n    for turbulent boundary layer .',
#   'processed_text': 'an experiment test of compress transform for turbul boundari layer',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1297,
#   'docno': np.int64(1300),
#   'title': 'some effects of bluntness on boundary layer transition\n    and heat transfer at supersonic speeds .',
#   'processed_text': 'some effect of blunt on boundari layer transit and heat transfer at superson speed',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1298,
#   'docno': np.int64(1301),
#   'title': 'compressible boundary layers on bodies of revolution .',
#   'processed_text': 'compress boundari layer on bodi of revolut',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1299,
#   'docno': np.int64(1302),
#   'title': 'the development of the boundary layer in supersonic\n    shear flow .',
#   'processed_text': 'the develop of the boundari layer in superson shear flow',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1308,
#   'docno': np.int64(1311),
#   'title': 'some simple solutions to the problem of predicting\n    boundary layer self-induced pressures .',
#   'processed_text': 'some simpl solut to the problem of predict boundari layer selfinduc pressur',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 291,
#   'docno': np.int64(292),
#   'title': 'rapid laminar boundary layer calculations by piece-wise\n    application of similar solutions .',
#   'processed_text': 'rapid laminar boundari layer calcul by piecewis applic of similar solut',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 292,
#   'docno': np.int64(293),
#   'title': 'recent studies on the effect of cooling on boundary\n    layer transition at mach 4.',
#   'processed_text': 'recent studi on the effect of cool on boundari layer transit at mach',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1319,
#   'docno': np.int64(1322),
#   'title': 'qualitiative solutions of the stability equation for a boundary layer in\n    contact with various forms of flexible surface .',
#   'processed_text': 'qualiti solut of the stabil equat for a boundari layer in contact with various form of flexibl surfac',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1321,
#   'docno': np.int64(1324),
#   'title': 'the effect on transition of isolated surface excrescences\n    in the boundary layer .',
#   'processed_text': 'the effect on transit of isol surfac excresc in the boundari layer',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 305,
#   'docno': np.int64(306),
#   'title': 'second approximation to laminar compressible boundary\n    layer on flat plate in slip flow .',
#   'processed_text': 'second approxim to laminar compress boundari layer on flat plate in slip flow',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 306,
#   'docno': np.int64(307),
#   'title': 'an approximate solution of hypersonic laminar boundary\n    layer equations and its application .',
#   'processed_text': 'an approxim solut of hyperson laminar boundari layer equat and it applic',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 313,
#   'docno': np.int64(314),
#   'title': 'simplified method for determination of the critical\n    height of distributed roughness particles for boundary\n    layer transition at mach numbers from 0 to 5.',
#   'processed_text': 'simplifi method for determin of the critic height of distribut rough particl for boundari layer transit at mach number from to',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 315,
#   'docno': np.int64(316),
#   'title': 'the occurrence and development of boundary layer separations at high\n    incidences and high speeds .',
#   'processed_text': 'the occurr and develop of boundari layer separ at high incid and high speed',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 324,
#   'docno': np.int64(325),
#   'title': 'heat transfer to constant property laminar boundary\n    layer flows with power function free stream velocity\n    and wall temperature variation .',
#   'processed_text': 'heat transfer to constant properti laminar boundari layer flow with power function free stream veloc and wall temperatur variat',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 325,
#   'docno': np.int64(326),
#   'title': 'forst-order slip effects on the compressible laminar\n    boundary layer over a slender body of revolution in\n    axial flow .',
#   'processed_text': 'forstord slip effect on the compress laminar boundari layer over a slender bodi of revolut in axial flow',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 326,
#   'docno': np.int64(327),
#   'title': 'on local flat plate similarity in the hypersonic boundary\n    layer .',
#   'processed_text': 'on local flat plate similar in the hyperson boundari layer',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 327,
#   'docno': np.int64(328),
#   'title': 'the boundary layer near the stagnation point in hypersonic\n    flow past a sphere .',
#   'processed_text': 'the boundari layer near the stagnat point in hyperson flow past a sphere',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1352,
#   'docno': np.int64(1355),
#   'title': 'boundary layer displacement effects in air at mach\n    numbers of 6. 8 and 9. 6.',
#   'processed_text': 'boundari layer displac effect in air at mach number of and',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 333,
#   'docno': np.int64(334),
#   'title': 'influence of the leading-edge shock wave on the laminar boundary layer\n    at hypersonic speeds .',
#   'processed_text': 'influenc of the leadingedg shock wave on the laminar boundari layer at hyperson speed',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 334,
#   'docno': np.int64(335),
#   'title': 'the interaction between boundary layer and shock waves in transonic\n    flow .',
#   'processed_text': 'the interact between boundari layer and shock wave in transon flow',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 335,
#   'docno': np.int64(336),
#   'title': 'simplified laminar boundary layer calculations for\n    bodies of revolution and for yawed wings .',
#   'processed_text': 'simplifi laminar boundari layer calcul for bodi of revolut and for yaw wing',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 336,
#   'docno': np.int64(337),
#   'title': 'boundary layer transition with gas injection .',
#   'processed_text': 'boundari layer transit with gas inject',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1361,
#   'docno': np.int64(1364),
#   'title': 'an experimental investigation of the interaction between shock waves and\n    boundary layers .',
#   'processed_text': 'an experiment investig of the interact between shock wave and boundari layer',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 338,
#   'docno': np.int64(339),
#   'title': 'experimental evaluation of heat transfer with transpiration\n    cooling in a turbulent boundary layer at m=3 .2.',
#   'processed_text': 'experiment evalu of heat transfer with transpir cool in a turbul boundari layer at m',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 339,
#   'docno': np.int64(340),
#   'title': 'analysis of effects of diffusion of a foreign gas into\n    the laminar boundary layer of a supersonic flow of\n    air in a tube .',
#   'processed_text': 'analysi of effect of diffus of a foreign gas into the laminar boundari layer of a superson flow of air in a tube',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1362,
#   'docno': np.int64(1365),
#   'title': 'approximate calculation of the laminar boundary layer .',
#   'processed_text': 'approxim calcul of the laminar boundari layer',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 341,
#   'docno': np.int64(342),
#   'title': 'effect of diffusion fields on the laminar boundary\n    layer .',
#   'processed_text': 'effect of diffus field on the laminar boundari layer',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 342,
#   'docno': np.int64(343),
#   'title': 'transpiration cooling experiments in a turbulent boundary\n    layer at m=3 .',
#   'processed_text': 'transpir cool experi in a turbul boundari layer at m',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1363,
#   'docno': np.int64(1366),
#   'title': 'the compressible laminar boundary layer with heat transfer\n    and arbitrary pressure gradient .',
#   'processed_text': 'the compress laminar boundari layer with heat transfer and arbitrari pressur gradient',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 344,
#   'docno': np.int64(345),
#   'title': 'the interaction of shock waves with boundary layer\n    on a flat surface .',
#   'processed_text': 'the interact of shock wave with boundari layer on a flat surfac',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1367,
#   'docno': np.int64(1370),
#   'title': 'some remarks on the flat plate boundary layer .',
#   'processed_text': 'some remark on the flat plate boundari layer',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 346,
#   'docno': np.int64(347),
#   'title': 'boundary layer measurements in hypersonic flow .',
#   'processed_text': 'boundari layer measur in hyperson flow',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 347,
#   'docno': np.int64(348),
#   'title': 'turbulent boundary layer in compressible fluids .',
#   'processed_text': 'turbul boundari layer in compress fluid',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 348,
#   'docno': np.int64(349),
#   'title': 'numerical solution of the boundary layer equations\n    without similarity assumptions .',
#   'processed_text': 'numer solut of the boundari layer equat without similar assumpt',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1369,
#   'docno': np.int64(1372),
#   'title': 'on axially symmetric, turbulent, compressible mixing in the presence\n    of initial boundary layer .',
#   'processed_text': 'on axial symmetr turbul compress mix in the presenc of initi boundari layer',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 354,
#   'docno': np.int64(355),
#   'title': 'the injection of air into the dissociated hypersonic laminar boundary\n    layer .',
#   'processed_text': 'the inject of air into the dissoci hyperson laminar boundari layer',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1378,
#   'docno': np.int64(1381),
#   'title': 'effect of mach number on boundary layer transition\n    in the presence of pressure rise and surface roughness\n    on an ogive-cylinder body with cold wall conditions .',
#   'processed_text': 'effect of mach number on boundari layer transit in the presenc of pressur rise and surfac rough on an ogivecylind bodi with cold wall condit',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1379,
#   'docno': np.int64(1382),
#   'title': "the solution of the equations of the laminar boundary\n    layer for schubauer's observed pressure distribution\n    for an elliptic cylinder .",
#   'processed_text': 'the solut of the equat of the laminar boundari layer for schubauer observ pressur distribut for an ellipt cylind',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 357,
#   'docno': np.int64(358),
#   'title': 'on the model of the free shock separation, turbulent\n    boundary layer .',
#   'processed_text': 'on the model of the free shock separ turbul boundari layer',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1380,
#   'docno': np.int64(1383),
#   'title': 'on the theory of laminar boundary layer involving separation .',
#   'processed_text': 'on the theori of laminar boundari layer involv separ',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1381,
#   'docno': np.int64(1384),
#   'title': 'a theoretical calculation of the laminar boundary layer\n    around an elliptic cylinder and its comparison with\n    experiment .',
#   'processed_text': 'a theoret calcul of the laminar boundari layer around an ellipt cylind and it comparison with experi',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1382,
#   'docno': np.int64(1385),
#   'title': 'air flow in a separating laminar boundary layer .',
#   'processed_text': 'air flow in a separ laminar boundari layer',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 1383,
#   'docno': np.int64(1386),
#   'title': 'analysis and calculation by integral methods of laminar\n    compressible boundary layer with heat transfer and\n    with and without pressure gradient .',
#   'processed_text': 'analysi and calcul by integr method of laminar compress boundari layer with heat transfer and with and without pressur gradient',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 363,
#   'docno': np.int64(364),
#   'title': 'a method for analysing the insulating properties of\n    the laminar compressible boundary layer .',
#   'processed_text': 'a method for analys the insul properti of the laminar compress boundari layer',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 364,
#   'docno': np.int64(365),
#   'title': 'the homogeneous boundary layer at an axisymmetric stagnation\n    point with large rates of injection .',
#   'processed_text': 'the homogen boundari layer at an axisymmetr stagnat point with larg rate of inject',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 365,
#   'docno': np.int64(366),
#   'title': 'helium injection into the boundary layer at an axisymmetric\n    stagnation point .',
#   'processed_text': 'helium inject into the boundari layer at an axisymmetr stagnat point',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 374,
#   'docno': np.int64(375),
#   'title': 'steady flow in the laminar boundary layer of a gas .',
#   'processed_text': 'steadi flow in the laminar boundari layer of a gas',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 375,
#   'docno': np.int64(376),
#   'title': 'transformation between compressible and incompressible\n    boundary layer equations .',
#   'processed_text': 'transform between compress and incompress boundari layer equat',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 380,
#   'docno': np.int64(381),
#   'title': 'the axisymmetric boundary layer on a long thin cylinder .',
#   'processed_text': 'the axisymmetr boundari layer on a long thin cylind',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 381,
#   'docno': np.int64(382),
#   'title': 'a note on the laminar boundary layer on a circular cylinder in\n    axial incompressible flow .',
#   'processed_text': 'a note on the laminar boundari layer on a circular cylind in axial incompress flow',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 382,
#   'docno': np.int64(383),
#   'title': 'integration of the boundary layer equations for a plane in compressible\n    flow with heat transfer .',
#   'processed_text': 'integr of the boundari layer equat for a plane in compress flow with heat transfer',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 396,
#   'docno': np.int64(397),
#   'title': 'a sublayer for fluid injection into the incompressible\n    turbulent boundary layer .',
#   'processed_text': 'a sublay for fluid inject into the incompress turbul boundari layer',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 405,
#   'docno': np.int64(406),
#   'title': 'on the behaviour of boundary layers at supersonic speeds .',
#   'processed_text': 'on the behaviour of boundari layer at superson speed',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 457,
#   'docno': np.int64(458),
#   'title': 'a new series for calculation of steady laminar boundary\n    layer flows .',
#   'processed_text': 'a new seri for calcul of steadi laminar boundari layer flow',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 458,
#   'docno': np.int64(459),
#   'title': 'on the solution of the laminar boundary layer equations .',
#   'processed_text': 'on the solut of the laminar boundari layer equat',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 459,
#   'docno': np.int64(460),
#   'title': 'correlated incompressible and compressible boundary\n    layers .',
#   'processed_text': 'correl incompress and compress boundari layer',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 460,
#   'docno': np.int64(461),
#   'title': 'approximate methods fore predicting separation properties\n    of laminar boundary layers .',
#   'processed_text': 'approxim method fore predict separ properti of laminar boundari layer',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 473,
#   'docno': np.int64(475),
#   'title': 'the velocity distribution in the laminar boundary layer\n    between parallel streams .',
#   'processed_text': 'the veloc distribut in the laminar boundari layer between parallel stream',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 475,
#   'docno': np.int64(477),
#   'title': 'laminar boundary layers at the interface of co-current\n    parallel streams .',
#   'processed_text': 'laminar boundari layer at the interfac of cocurr parallel stream',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 477,
#   'docno': np.int64(479),
#   'title': "on an equation occurring in falkner and skan's approximate\n    treatment of the equation of the boundary layer .",
#   'processed_text': 'on an equat occur in falkner and skan approxim treatment of the equat of the boundari layer',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 479,
#   'docno': np.int64(481),
#   'title': 'mass transfer cooling of a laminary boundary layer\n    by injection of a light weight foreign gas .',
#   'processed_text': 'mass transfer cool of a laminari boundari layer by inject of a light weight foreign gas',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 491,
#   'docno': np.int64(493),
#   'title': 'real-gas laminar boundary layer skin friction and heat\n    transfer .',
#   'processed_text': 'realga laminar boundari layer skin friction and heat transfer',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 502,
#   'docno': np.int64(504),
#   'title': 'stability of compressible boundary layers induced by\n    a moving wave .',
#   'processed_text': 'stabil of compress boundari layer induc by a move wave',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 525,
#   'docno': np.int64(527),
#   'title': 'note on the three-point boundary layer problem for\n    the blasius equations .',
#   'processed_text': 'note on the threepoint boundari layer problem for the blasius equat',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 526,
#   'docno': np.int64(528),
#   'title': 'first-order slip effects on the laminar boundary layer over a slender\n    body of revolution with zero pressure gradient .',
#   'processed_text': 'firstord slip effect on the laminar boundari layer over a slender bodi of revolut with zero pressur gradient',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 527,
#   'docno': np.int64(529),
#   'title': 'some effects of injection of foreign gases in a decelerating\n    laminar boundary layer in supersonic flow .',
#   'processed_text': 'some effect of inject of foreign gase in a deceler laminar boundari layer in superson flow',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 536,
#   'docno': np.int64(538),
#   'title': 'the conpressibility transformation and the turbulent\n    boundary layer equations .',
#   'processed_text': 'the conpress transform and the turbul boundari layer equat',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 545,
#   'docno': np.int64(547),
#   'title': 'boundary layer characteristics of caret wings .',
#   'processed_text': 'boundari layer characterist of caret wing',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 558,
#   'docno': np.int64(560),
#   'title': 'a theoretical study of the effect of upstream\n    transpiration-cooling on the heat transfer and skin friction characteristics\n    of a compressible laminar boundary layer .',
#   'processed_text': 'a theoret studi of the effect of upstream transpirationcool on the heat transfer and skin friction characterist of a compress laminar boundari layer',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 560,
#   'docno': np.int64(562),
#   'title': 'concerning the effect of compressibility on laminar\n    boundary layers and their separation .',
#   'processed_text': 'concern the effect of compress on laminar boundari layer and their separ',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 561,
#   'docno': np.int64(563),
#   'title': 'the law of the wake in the turbulent boundary layer .',
#   'processed_text': 'the law of the wake in the turbul boundari layer',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 563,
#   'docno': np.int64(565),
#   'title': 'similar solutions for the compressible boundary layer\n    on a yawed cylinder with transpiration cooling .',
#   'processed_text': 'similar solut for the compress boundari layer on a yaw cylind with transpir cool',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 567,
#   'docno': np.int64(569),
#   'title': 'an experimental investigation of leading edge shock wave boundary layer\n    interaction at mach 5.8 .',
#   'processed_text': 'an experiment investig of lead edg shock wave boundari layer interact at mach',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 568,
#   'docno': np.int64(570),
#   'title': 'on the boundary layer equations in hypersonic flow\n    and their approximate solutions .',
#   'processed_text': 'on the boundari layer equat in hyperson flow and their approxim solut',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 570,
#   'docno': np.int64(572),
#   'title': 'boundary layer displacement and leading edge bluntness effects in high\n    temperature hypersonic flow .',
#   'processed_text': 'boundari layer displac and lead edg blunt effect in high temperatur hyperson flow',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 609,
#   'docno': np.int64(611),
#   'title': 'an approximate solution of the compressible laminar\n    boundary layer on a flat plate .',
#   'processed_text': 'an approxim solut of the compress laminar boundari layer on a flat plate',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 627,
#   'docno': np.int64(629),
#   'title': 'second-order effects in laminar boundary layers .',
#   'processed_text': 'secondord effect in laminar boundari layer',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 643,
#   'docno': np.int64(645),
#   'title': 'thermodynamic coupling in boundary layers .',
#   'processed_text': 'thermodynam coupl in boundari layer',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 644,
#   'docno': np.int64(646),
#   'title': 'thermal diffusion effects on energy transfer in a turbulent\n    boundary layer with helium injection .',
#   'processed_text': 'thermal diffus effect on energi transfer in a turbul boundari layer with helium inject',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 653,
#   'docno': np.int64(655),
#   'title': 'effects of boundary layer displacement and leading edge bluntness on\n    pressure distribution, skin friction, and heat transfer of bodies at\n    hypersonic speeds .',
#   'processed_text': 'effect of boundari layer displac and lead edg blunt on pressur distribut skin friction and heat transfer of bodi at hyperson speed',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 659,
#   'docno': np.int64(661),
#   'title': 'summary of laminar boundary layer solutions for\n    wedge-type flow over convection and transpiration cooled\n    surfaces .',
#   'processed_text': 'summari of laminar boundari layer solut for wedgetyp flow over convect and transpir cool surfac',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 660,
#   'docno': np.int64(662),
#   'title': 'theoretical and experimental investigation of\n    aerodynamic-heating and isothermal heat transfer parameters on\n    a hemisphere nose with laminar boundary layer at supersonic\n    mach numbers .',
#   'processed_text': 'theoret and experiment investig of aerodynamich and isotherm heat transfer paramet on a hemispher nose with laminar boundari layer at superson mach number',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 662,
#   'docno': np.int64(664),
#   'title': 'the boundary layer on a flat plate in a stream with\n    uniform shear .',
#   'processed_text': 'the boundari layer on a flat plate in a stream with uniform shear',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 752,
#   'docno': np.int64(754),
#   'title': 'heat transfer through laminar boundary layers on\n    semi-infinite cylinders of arbitrary cross section .',
#   'processed_text': 'heat transfer through laminar boundari layer on semiinfinit cylind of arbitrari cross section',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 782,
#   'docno': np.int64(784),
#   'title': 'heat transfer through the laminar boundary layer on\n    a circular cylinder in axial incompressible flow .',
#   'processed_text': 'heat transfer through the laminar boundari layer on a circular cylind in axial incompress flow',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 786,
#   'docno': np.int64(788),
#   'title': 'an approximate boundary layer theory for semi-infinite cylinders of\n    arbitrary cross-section .',
#   'processed_text': 'an approxim boundari layer theori for semiinfinit cylind of arbitrari crosssect',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 787,
#   'docno': np.int64(789),
#   'title': 'a further note on the calculation of heat transfer\n    through the axisymmetrical laminar boundary layer on\n    a circular cylinder .',
#   'processed_text': 'a further note on the calcul of heat transfer through the axisymmetr laminar boundari layer on a circular cylind',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 794,
#   'docno': np.int64(796),
#   'title': 'an investigation at transonic speeds of the performance of various\n    distributed roughness bands used to cause boundary layer transition\n    near the leading edge of a cropped delta half-wing .',
#   'processed_text': 'an investig at transon speed of the perform of various distribut rough band use to caus boundari layer transit near the lead edg of a crop delta halfw',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 796,
#   'docno': np.int64(798),
#   'title': 'interaction between shock waves and boundary layers, with a note on the\n    effects of the interaction of the performance of supersonic intakes .',
#   'processed_text': 'interact between shock wave and boundari layer with a note on the effect of the interact of the perform of superson intak',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 870,
#   'docno': np.int64(872),
#   'title': 'fundamentals of boundary layer heat transfer with streamwise\n    temperature variations .',
#   'processed_text': 'fundament of boundari layer heat transfer with streamwis temperatur variat',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 897,
#   'docno': np.int64(899),
#   'title': 'aerodynamic effects on boundary layer unsteadiness .',
#   'processed_text': 'aerodynam effect on boundari layer unsteadi',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 960,
#   'docno': np.int64(962),
#   'title': 'contributions to the theory of heat transfer through\n    a laminar boundary layer .',
#   'processed_text': 'contribut to the theori of heat transfer through a laminar boundari layer',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 975,
#   'docno': np.int64(977),
#   'title': 'concerning some solutions of the boundary layer equations\n    in hydrodynamics .',
#   'processed_text': 'concern some solut of the boundari layer equat in hydrodynam',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 977,
#   'docno': np.int64(979),
#   'title': 'correlation of base pressure and wake structure of\n    sharp and blunt-nose cones with reynolds number based\n    on boundary layer momentum thickness .',
#   'processed_text': 'correl of base pressur and wake structur of sharp and bluntnos cone with reynold number base on boundari layer momentum thick',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 993,
#   'docno': np.int64(996),
#   'title': 'extension of boundary layer separation criteria to\n    a m=6 .5 utilizing flat plates with forward-facing\n    steps .',
#   'processed_text': 'extens of boundari layer separ criteria to a m util flat plate with forwardfac step',
#   'tfidf_score': np.float64(1.4141674281192098)},
#  {'doc_id': 71,
#   'docno': np.int64(72),
#   'title': 'boundary layer behind shock or thin expansion wave\n    moving into stationary fluid .',
#   'processed_text': 'boundari layer behind shock or thin expans wave move into stationari fluid',
#   'tfidf_score': np.float64(1.3873597715856316)},
#  {'doc_id': 1106,
#   'docno': np.int64(1109),
#   'title': 'unsteady laminar compressible boundary layers on an\n    infinite plate with suction or injection .',
#   'processed_text': 'unsteadi laminar compress boundari layer on an infinit plate with suction or inject',
#   'tfidf_score': np.float64(1.3873597715856316)},
#  {'doc_id': 524,
#   'docno': np.int64(526),
#   'title': 'leading edge attachment in transonic flow with laminar\n    or turbulent boundary layers .',
#   'processed_text': 'lead edg attach in transon flow with laminar or turbul boundari layer',
#   'tfidf_score': np.float64(1.3873597715856316)},
#  {'doc_id': 265,
#   'docno': np.int64(266),
#   'title': 'exact solution of the neumann problem . calculation\n    for non- circulatory plane and axially symmetric flows\n    about or within arbitrary boundaries .',
#   'processed_text': 'exact solut of the neumann problem calcul for non circulatori plane and axial symmetr flow about or within arbitrari boundari',
#   'tfidf_score': np.float64(1.196821603333893)},
#  {'doc_id': 58,
#   'docno': np.int64(59),
#   'title': 'tables of exact laminar-boundary layer solutions when\n    the wall is porous and fluid properties are variable .',
#   'processed_text': 'tabl of exact laminarboundari layer solut when the wall is porous and fluid properti are variabl',
#   'tfidf_score': np.float64(1.0)},
#  {'doc_id': 73,
#   'docno': np.int64(74),
#   'title': 'an experimental study of the turbulen coundary layer\n    on a shock tube wall .',
#   'processed_text': 'an experiment studi of the turbulen coundari layer on a shock tube wall',
#   'tfidf_score': np.float64(1.0)},
#  {'doc_id': 1104,
#   'docno': np.int64(1107),
#   'title': 'the flow field over blunted flat plates and its effect\n    on turbulent boundary growth and heat transfer at a\n    mach number of 4. 7.',
#   'processed_text': 'the flow field over blunt flat plate and it effect on turbul boundari growth and heat transfer at a mach number of',
#   'tfidf_score': np.float64(1.0)},
#  {'doc_id': 118,
#   'docno': np.int64(119),
#   'title': 'conduction of fluctuating heat flow in a wall consisting\n    of many layers .',
#   'processed_text': 'conduct of fluctuat heat flow in a wall consist of mani layer',
#   'tfidf_score': np.float64(1.0)},
#  {'doc_id': 1232,
#   'docno': np.int64(1235),
#   'title': 'a theory of the two dimensional laminar bounary layer\n    over a curved surface .',
#   'processed_text': 'a theori of the two dimension laminar bounari layer over a curv surfac',
#   'tfidf_score': np.float64(1.0)},
#  {'doc_id': 1296,
#   'docno': np.int64(1299),
#   'title': 'hypersonic viscous shock layer .',
#   'processed_text': 'hyperson viscous shock layer',
#   'tfidf_score': np.float64(1.0)},
#  {'doc_id': 1318,
#   'docno': np.int64(1321),
#   'title': 'effects of a flexible boundary on hydrodynamic stability .',
#   'processed_text': 'effect of a flexibl boundari on hydrodynam stabil',
#   'tfidf_score': np.float64(1.0)},
#  {'doc_id': 319,
#   'docno': np.int64(320),
#   'title': 'comment on improved numerical solution of the blasius problem with\n    three-point boundary conditions .',
#   'processed_text': 'comment on improv numer solut of the blasius problem with threepoint boundari condit',
#   'tfidf_score': np.float64(1.0)},
#  {'doc_id': 320,
#   'docno': np.int64(321),
#   'title': 'improved numerical solution of the blasius problem with three-point\n    boundary conditions .',
#   'processed_text': 'improv numer solut of the blasius problem with threepoint boundari condit',
#   'tfidf_score': np.float64(1.0)},
#  {'doc_id': 321,
#   'docno': np.int64(322),
#   'title': 'on the numerical solution of the blasius problem with three-point\n    boundary conditions .',
#   'processed_text': 'on the numer solut of the blasius problem with threepoint boundari condit',
#   'tfidf_score': np.float64(1.0)},
#  {'doc_id': 1353,
#   'docno': np.int64(1356),
#   'title': 'secondary flow fields embedded in hypersonic shock\n    layers .',
#   'processed_text': 'secondari flow field embed in hyperson shock layer',
#   'tfidf_score': np.float64(1.0)},
#  {'doc_id': 474,
#   'docno': np.int64(476),
#   'title': 'the blasius equation with three-point boundary conditions .',
#   'processed_text': 'the blasius equat with threepoint boundari condit',
#   'tfidf_score': np.float64(1.0)},
#  {'doc_id': 646,
#   'docno': np.int64(648),
#   'title': 'the approximate analysis of certain boundary value\n    problems .',
#   'processed_text': 'the approxim analysi of certain boundari valu problem',
#   'tfidf_score': np.float64(1.0)},
#  {'doc_id': 665,
#   'docno': np.int64(667),
#   'title': 'hypersonic shock layer theory of the stagnation region at low reynolds\n    number .',
#   'processed_text': 'hyperson shock layer theori of the stagnat region at low reynold number',
#   'tfidf_score': np.float64(1.0)},
#  {'doc_id': 729,
#   'docno': np.int64(731),
#   'title': 'upper and lower bounds for the solution of the first\n    biharmonic boundary value problem .',
#   'processed_text': 'upper and lower bound for the solut of the first biharmon boundari valu problem',
#   'tfidf_score': np.float64(1.0)},
#  {'doc_id': 853,
#   'docno': np.int64(855),
#   'title': 'simplified formulas for boundary value problems of\n    the thin-- walled circular cylinder .',
#   'processed_text': 'simplifi formula for boundari valu problem of the thin wall circular cylind',
#   'tfidf_score': np.float64(1.0)},
#  {'doc_id': 938,
#   'docno': np.int64(940),
#   'title': 'of a turbulent free shear layer .',
#   'processed_text': 'of a turbul free shear layer',
#   'tfidf_score': np.float64(1.0)},
#  {'doc_id': 941,
#   'docno': np.int64(943),
#   'title': 'compressible free shear layer with finite initial thickness .',
#   'processed_text': 'compress free shear layer with finit initi thick',
#   'tfidf_score': np.float64(1.0)},
#  {'doc_id': 976,
#   'docno': np.int64(978),
#   'title': 'temperature profiles inafinite solid with moving boundary .',
#   'processed_text': 'temperatur profil inafinit solid with move boundari',
#   'tfidf_score': np.float64(1.0)},
#  {'doc_id': 979,
#   'docno': np.int64(981),
#   'title': 'solutions to the heat-conduction equation with time dependent boundary\n    conditions .',
#   'processed_text': 'solut to the heatconduct equat with time depend boundari condit',
#   'tfidf_score': np.float64(1.0)}]

# %%
def search(query, df, top_k=5):
    # index_path = os.path.abspath("./CranfieldTitleIndex")
    # if not os.path.exists(index_path) or not os.listdir(index_path):
    #     print("Index not found. Run Regular_indexing() first.")
    #     return

    # index = pt.IndexFactory.of(index_path)
    
    print(f'\n=== Searching for: "{query}" ===')
    query_tokens = preprocess_query(query)
    print('Query tokens:', query_tokens)

    documents = retrieve_documents(query_tokens, df)
    if not documents:
        print('No documents found.')
        return
    print(f'Found {len(documents)} documents.')

    ranked_docs = rank_documents(documents, query_tokens)

    print(f'Top {min(top_k, len(ranked_docs))} results:')
    for i, doc in enumerate(ranked_docs[:top_k], 1):
        print(f'{i}. Docno: {doc["docno"]}, Title: {doc["title"]}, TF-IDF Score: {doc["tfidf_score"]:.4f}')

search('experimental investigation', df)
search('information retrieval', df)
search('nonexistent term', df)
# Out:
# === Searching for: "experimental investigation" ===
# Query tokens: ['experiment', 'investig']
# Term 'experiment' not found in index.
# No documents found.
#
# === Searching for: "information retrieval" ===
# Query tokens: ['inform', 'retriev']
# Term 'retriev' not found in index.
# No documents found.
#
# === Searching for: "nonexistent term" ===
# Query tokens: ['nonexist', 'term']
# Term 'nonexist' not found in index.
# No documents found.

# %% [markdown]
# Testing

# %%
def main():
    print("=== Step 1: Choose the Searching method ===")
    print("1. Regular Indexing + Search")
    print("2. Boolean Retreivel")
    print("3. TF-IDF Retreivel")

    option = int(input("Enter the number of the search: "))
    
    if option == 1:
        Regular_indexing()
        query = input("Enter your query: ")
        query_terms=preprocess_query(query)
        search_term_regular_indexing(query_terms)
        print("================Retreving the Query=================")
        retrieve_documents(query_terms,df)
        
    if option == 2 :

        query = input("Enter your the words: ")
        # operator=input("Enter the Operator {AND,OR,NOT} : ")
        # print(boolean_query(query, operator.upper()))
        boolean_search(query,df)
    if option ==3 : 
        query=input("Enter your the words: ")
        search(query,df,top_k=5)

# %%
if main==main() :
    main()
# Out:
# === Step 1: Choose the Searching method ===
# 1. Regular Indexing + Search
# 2. Boolean Retreivel
# 3. TF-IDF Retreivel
#
# === Searching for: "experimental investigation" ===
# Query tokens: ['experiment', 'investig']
# Term 'experiment' not found in index.
# No documents found.
